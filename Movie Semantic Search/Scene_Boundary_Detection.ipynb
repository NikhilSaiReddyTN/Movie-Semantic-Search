# %%
def checkSpaces(string):
    count=0
    for i in string:
        if i==" ":
            count+=1
        else:
            break
            
    return count

# %%
import PyPDF2 
    
# creating a pdf file object 
pdfFileObj = open('You_ve+Got+Mail.pdf', 'rb') 
    
# creating a pdf reader object 
pdfReader = PyPDF2.PdfFileReader(pdfFileObj) 
    
# printing number of pages in pdf file 
#print(pdfReader.numPages) 
    
# creating a page object 
pageObj = pdfReader.getPage(1) 
    
# extracting text from page 
mylist  = (pageObj.extractText()).splitlines()
for i in mylist:
    print(i)
#print(pageObj.extractText()) 
    
# closing the pdf file object 
pdfFileObj.close()
# Out:
#  fresh as a spring day.  Her bedroom cozy, has a queen -sized
#  bed and a desk with a computer on it.  Bookshelves line every
#  inch of wall space and overflow with books.  Framed on the
#  children's classic.  Madeleine.
#
#  As Kathleen wakes up, her boyfriend FRANK NAVASKY walks into
#  the room.  He wears blue jeans and a workshirt.  He's carrying
#  the New York Times.
#
#     KATHLEEN
#   Good morning.
#
#     FRANK
#    (as he reads)
#   Listen to this -- the entire work force
#   of the state of Virginia had to have
#   solitaire removed from their computers --
#
#  Kathleen gets out of bed and goes to brush her teeth in the
#  bathroom, and we stay with Frank.
#
#     FRANK
#    (continuing)
#   -- because they hadn't done any work in
#   six weeks.
#
#  Kathleen comes out of the bathroom in her robe.
#
#     KATHLEEN
#   Aren't you late?
#
#     FRANK
#    (continuing)
#   You know what this is, you know what
#   we're seeing here?  We're seeing the end
# ...

# %%
pip install PyPDF2
# Out:
# ...
#      -------------------------------------- 216.9/216.9 kB 1.3 MB/s eta 0:00:00
# ...
#
# [notice] A new release of pip available: 22.1.2 -> 22.2.2
# [notice] To update, run: python.exe -m pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
print(mylist[0])
# Out:
#  fresh as a spring day.  Her bedroom cozy, has a queen -sized

# %%
checkSpaces(mylist[0])
# Out:
# 1

# %%
import PyPDF2 
    
# creating a pdf file object 
pdfFileObj = open('The_Pacifier.pdf', 'rb') 
    
# creating a pdf reader object 
pdfReader = PyPDF2.PdfFileReader(pdfFileObj, strict=False) 
    
# printing number of pages in pdf file 
#print(pdfReader.numPages) 
    
# creating a page object 
pageObj = pdfReader.getPage(2) 
    
# extracting text from page 
mylist  = (pageObj.extractText()).splitlines()
for i in mylist:
    print(i)
#print(pageObj.extractText()) 
    
# closing the pdf file object 
pdfFileObj.close()
# Out:
# 2.
# BOOM.  A dense explosion sends ripples through the water
# and ELECTRICITY crackling around the boat.
# INT. FISHING BOAT/CONTROL DECK - CONTINUOUS
# A SURGE of ELECTRICAL FORCE blasts from the control
# panel. SPARKS fly.
# The two Serbian Men jolt backwards -- WHAM -- and hit the
# wall. All the needles inside all the dials go LIMP. The
# roar of the engines DIES and the boat STOPS.
# EXT. PACIFIC OCEAN, UNDER THE BOAT - CONTINUOUS
# Shane slips inside the hull, through the new hole.
# INT. SEA HAWK 1 - CONTINUOUS
# The chopper slows to a hover.  The Pilot looks below.
# PILOT
# What’s happening?
# EXT. PACIFIC OCEAN - CONTINUOUS
# The jet skiers protectively circle the injured boat in a
# SYNCHRONIZED SWIMMING  move, and the Jet Ski drivers are
# simultaneously YANKED below the surface: a split second
# later they’re replaced by our SEALS ( ALSO IN BLACK WET
# SUITS AND GOGGLES ) -- the switch happens in less than a
# second, way too fast for anyone to notice.
# ...

# %%
pip install python-docx
# Out:
# ...
#      ---------------------------------------- 5.6/5.6 MB 13.6 MB/s eta 0:00:00
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# ...
#   Created wheel for python-docx: filename=python_docx-0.8.11-py3-none-any.whl size=184489 sha256=e5758619dc017ae24a28cbc3b657ae33e4c6e3a0ad57600304c4fa1729442607
#   Stored in directory: c:\users\tirun\appdata\local\pip\cache\wheels\83\8b\7c\09ae60c42c7ba4ed2dddaf2b8b9186cb105255856d6ed3dba5
# Successfully built python-docx
# ...
#
# [notice] A new release of pip available: 22.1.2 -> 22.2.2
# [notice] To update, run: python.exe -m pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
from docx import Document

document = Document('The_Pacifier.docx')

for i in range(len(document.paragraphs)):
    
    print(document.paragraphs[i].text)
# Out:
# The Pacifier
#
# by
# Thomas Lennon & Robert Ben Garant
#
# Previous Revisions by Jason Fulardi & Scott Alexander
# & Larry Karaszewki
#
# Current Revisions by Thomas Lennon & Robert Ben Garant
#
#
#
#
#
#
#
#
#
#
#
#
# Marked Revisions * March 3rd, 2004
#
# FADE IN:
# EXT. PACIFIC OCEAN - DAY
#
# A fishing boat pushes over choppy water. FOUR GUN TOTING MEN on Jet Skis wearing black wet suits and goggles escort the boat. Flying above it is a HELICOPTER.
# INT. FISHING BOAT/CONTROL DECK - CONTINUOUS
#
# A SERBIAN MAN captains the wheel. SERB 2 scans the horizon with binoculars. He checks the GPS system, then his watch, then speaks into his throat mic. All italics are Serbian w/ subtitles:
# SERB 2
# Fifteen minutes to delivery.
# EXT. PACIFIC OCEAN - CONTINUOUS
# The JET SKIER in the lead weighs in on a radio. INT. SEA HAWK 1 - CONTINUOUS
# The HELICOPTER PILOT weighs in.
# PILOT
# All clear from above.
# EXT. SKY - CONTINUOUS
#
# ...

# %%
import codecs
file = codecs.open("Devil-Wears-Prada,-The.html", "r", "utf-8")
mylist = file.read().splitlines()
for i in mylist: print(i)
# Out:
# <!-- saved from url=(0053)https://imsdb.com/scripts/Devil-Wears-Prada,-The.html -->
# <html><head><meta http-equiv="Content-Type" content="text/html; charset=UTF-8"><meta name="viewport" content="width=device-width, initial-scale=1">
# <meta name="HandheldFriendly" content="true">
#
# <meta http-equiv="Content-Language" content="EN">
#
# <meta name="objecttype" content="Document">
# <meta name="ROBOTS" content="INDEX, FOLLOW">
# <meta name="Subject" content="Movie scripts, Film scripts">
# <meta name="rating" content="General">
# <meta name="distribution" content="Global">
# <meta name="revisit-after" content="2 days">
#
# <link href="./Devil-Wears-Prada,-The_files/style.css" rel="stylesheet" type="text/css">
#
# <script type="text/javascript" async="" src="./Devil-Wears-Prada,-The_files/ga.js.download"></script><script type="text/javascript">
#   var _gaq = _gaq || [];
#   _gaq.push(['_setAccount', 'UA-3785444-3']);
#   _gaq.push(['_trackPageview']);
#
#   (function() {
# ...

# %%
s = '                Honey, you want West 57th.\r\n\r\n'
s1= '     '
match = re.compile( '(\s{16})((\w+\W? )+).' )
expr = match.findall(s) 
print(expr)
print(bool(expr))
# Out:
# [('                ', 'Honey, you want West ', 'West ')]
# True

# %%
from bs4 import BeautifulSoup
import urllib.request 

response = urllib.request.urlopen('https://imsdb.com/scripts/Devil-Wears-Prada,-The.html')

html_doc = response.read()
soup = BeautifulSoup(html_doc, 'html.parser')
i=0


for x in soup.find('pre'):
    if i==1:
        break                                               #don't know why it has many iterable objects
    list_with_b = x.find_all_next('b')                     #but each obj returns same value
    i+=1
    
script = soup.find('pre')
#print(script)

    
new_list = []  
for count,x in enumerate(script):
    #print(x.get_text())
    new_list.append(str(x.get_text()))
    #print(count,str(x.get_text()))

print(new_list)

"""  
#list_with_b.
new_list = []
for i in list_with_b: 
    new_list.append(str(i))
    
print(new_list)                                         #each item in the list is a bs4.element.Tag type

#for i in new_list: print(i)
"""
# Out:
# ['\r\n\r\n\r\n', '                        THE DEVIL WEARS PRADA\r\n', '\r\n\r\n\r\n                             Written by\r\n\r\n                        Aline Brosh McKenna\r\n\r\n\r\n\r\n             Based on the novel by Lauren Weisberger\r\n\r\n\r\n\r\n\r\n                                Shooting Draft - September 9, 2005\r\n                               Blue Revisions - September 15, 2005\r\n                               Pink Revisions - September 20, 2005\r\n                                 Green Revisions - October 9, 2005\r\n                               Yellow Revisions - November 9, 2005\r\n                           Goldenrod Revisions - November 14, 2005\r\n                               Salmon Revisions - December 9, 2005\r\n                                              2nd Blue In Progress\r\n\r\n', '       MUSIC UP\r\n', '\r\n', '       FADE IN\r\n', '\r\n', '       STEAM ON A MIRROR\r\n', "\r\n1      ...wiped off by ANDY SACHS, 20's, pretty but not glamorous,      
# ...

# %%
string = str(list_with_b[0])
print(string)
# Out:
# <b>                        THE DEVIL WEARS PRADA
# </b>

# %%
import re

string = '29   EXT. STARBUCKS -- DAY                                                    29\r\n'
#string = "               So you don't read Runway?\r\n\r\n"
match = re.compile('[0-9]+\s{3-6}([A-Z]+\s?\W*\s?)+[A-Z]+[0-9]+\Z')
expr = match.finditer(s) 
print(expr)
for i in expr:print(i)
#print(bool(expr))

# %%
s ='29   EXT. STARBUCKS -- DAY                                                    29'
#match = re.compile('[^\<b>[0-9]+\s|\s\s|\s\s\s|\s\s\s\s[A-Z]+[0-9]+ ')
match = re.compile(r'[0-9]+\s{3}([A-Z]+\s?\W*\s?)+[A-Z]+\s+[0-9]+')
expr = match.findall(s) 
print(expr)
print(bool(expr))
# Out:
# ['DA']
# True

# %%
import pysrt
subs = pysrt.open("the devil wears prada-English.srt")

sub_text = []
for sub in subs:
    sub_text.append((sub.text,sub.start))
    
k=0
print(sub_text)
"""for i,j in sub_text:
    print(k,i,j)
    k+=1
"""
# Out:
# [('Good luck.', SubRipTime(0, 1, 58, 991)), ('Hi. I have an appointment with...', SubRipTime(0, 3, 39, 216)), ('...Emily Charlton?', SubRipTime(0, 3, 42, 303)), ('- Andrea Sachs?\n- Yes?', SubRipTime(0, 3, 44, 763)), ('Great. Human Resources certainly has\nan odd sense of humor. Follow me.', SubRipTime(0, 3, 47, 433)), ("Okay. So I was Miranda's\nsecond assistant...", SubRipTime(0, 3, 54, 64)), ("...but her first recently got promoted,\nand now I'm the first.", SubRipTime(0, 3, 57, 67)), ("- You're replacing yourself.\n- Well, I am trying.", SubRipTime(0, 4, 0, 237)), ('Miranda sacked the last two girls\nafter a few weeks.', SubRipTime(0, 4, 2, 615)), ('We need someone\nwho can survive here.', SubRipTime(0, 4, 5, 284)), ("- Do you understand?\n- Yeah, of course. Who's Miranda?", SubRipTime(0, 4, 7, 244)), ('Oh, my God. I will pretend\nyou did not just ask me that.', SubRipTime(0, 4, 10, 372)), ("She's the editor in chief of Runway.\nNot to mention, a legend.", SubRipTime(0, 4, 13, 29
# ...

# %%
scene = False
sub=0

for line in script:
    if(isSceneStart(line)):
        scene = True
        continue
    if(compare(sub_text[sub],line)):
        
        if(scene==True):
            scene = False
            update_scene()
            sub+=1
        else:
            
            sub+=1
# Out:
# ['\r\n\r\n\r\n']
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_2612/1986345482.py in <module>
#       3
#       4 for line in script:
# ----> 5     if(isSceneStart(line)):
#       6         scene = True
#       7         continue
#
# ~\AppData\Local\Temp/ipykernel_2612/4264676440.py in isSceneStart(string)
#       3 def isSceneStart(string):
#       4     match = re.compile('[^\<b>[0-9]+\s|\s\s|\s\s\s|\s\s\s\s[A-Z].')
# ----> 5     expr = match.findall(string)
#       6     print(expr)
#       7     return bool(match)
#
# TypeError: expected string or bytes-like object

# %%
str1 = " Human Resources certainly has \n bizarre sense of humor.\n (sigh, annoyed) \n Follow me."
str2 = "Great. Human Resources certainly has\nan odd sense of humor. Follow me"
str3 = "Resources"

print(bool(str3 in str1))
print(bool(str2 in str1))
# Out:
# True
# False

# %%
from nltk.corpus import stopwords 
from nltk.tokenize import word_tokenize 
  
X = input("Enter first string: ").lower() 
Y = input("Enter second string: ").lower() 
   
X_list = word_tokenize(X)  
Y_list = word_tokenize(Y) 
  
sw = stopwords.words('english')  
l1 =[];l2 =[] 
   
X_set = {w for w in X_list if not w in sw}  
Y_set = {w for w in Y_list if not w in sw} 
    
rvector = X_set.union(Y_set)  
for w in rvector: 
    if w in X_set: l1.append(1)
    else: l1.append(0) 
    if w in Y_set: l2.append(1) 
    else: l2.append(0) 
        
c = 0
    
for i in range(len(rvector)): 
        c+= l1[i]*l2[i] 
cosine = c / float((sum(l1)*sum(l2))**0.5) 
print("similarity: ", cosine)
# Out:
# Enter first string: Hello There
# Enter second string: Hello how are you?
# similarity:  0.7071067811865475

# %%
from nltk.corpus import stopwords 
from nltk.tokenize import word_tokenize 

def compare(str1,str2):
    
    X = str1.lower() 
    Y = str2.lower() 

    X_list = word_tokenize(X)  
    Y_list = word_tokenize(Y) 

    sw = stopwords.words('english')  
    l1 =[];l2 =[] 

    X_set = {w for w in X_list if not w in sw}  
    Y_set = {w for w in Y_list if not w in sw} 
    
    if(len(X_set) == 0 or len(Y_set) == 0):
        return -1
    
    rvector = X_set.union(Y_set)  
    for w in rvector: 
        if w in X_set: l1.append(1)
        else: l1.append(0) 
        if w in Y_set: l2.append(1) 
        else: l2.append(0) 

    c = 0

    for i in range(len(rvector)): 
            c+= l1[i]*l2[i] 
            
    cosine = c / float((sum(l1)*sum(l2))**0.5) 
    
    return cosine

# %%
count=1
a,b = sub_text[count]
while count<500:
    if(len(a)==0 or len(new_list[count])==0):
        print("EMPTY")
        continue
    print(count,new_list[count],a,compare(a,new_list[count]))
    count+=1
# Out:
# 1                         THE DEVIL WEARS PRADA
#  Hi. I have an appointment with... 0.0
# 2
#
#
#                              Written by
#
#                         Aline Brosh McKenna
#
#
#
#              Based on the novel by Lauren Weisberger
#
#
#
#
#                                 Shooting Draft - September 9, 2005
#                                Blue Revisions - September 15, 2005
#                                Pink Revisions - September 20, 2005
#                                  Green Revisions - October 9, 2005
#                                Yellow Revisions - November 9, 2005
#                            Goldenrod Revisions - November 14, 2005
#                                Salmon Revisions - December 9, 2005
#                                               2nd Blue In Progress
#
#  Hi. I have an appointment with... 0.0
# 3        MUSIC UP
#  Hi. I have an appointment with... 0.0
# 4
#  Hi. I have an appointment with... -1
# 5        FADE IN
# ...

# %%
from sentence_similarity import sentence_similarity

model=sentence_similarity(model_name='distilbert-base-uncased',embedding_type='sentence_embedding')

def compare2(str1,str2):
    score=model.get_score(str1,str2,metric="cosine")
    return score
# Out:
# WARNING:root:No sentence-transformers model found with name C:\Users\tirun/.cache\torch\sentence_transformers\distilbert-base-uncased. Creating a new one with MEAN pooling.
# Some weights of the model checkpoint at C:\Users\tirun/.cache\torch\sentence_transformers\distilbert-base-uncased were not used when initializing DistilBertModel: ['vocab_projector.weight', 'vocab_layer_norm.weight', 'vocab_transform.weight', 'vocab_layer_norm.bias', 'vocab_projector.bias', 'vocab_transform.bias']
# - This IS expected if you are initializing DistilBertModel from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing DistilBertModel from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).

# %%
count=1
a,b = sub_text[count]
while count<500:
    if(len(a)==0 or len(new_list[count])==0):
        print("EMPTY")
        continue
    print(count,new_list[count],a,compare2(a,new_list[count]))
    count+=1
# Out:
# 1                         THE DEVIL WEARS PRADA
#  Hi. I have an appointment with... 0.619
# 2
#
#
#                              Written by
#
#                         Aline Brosh McKenna
#
#
#
#              Based on the novel by Lauren Weisberger
#
#
#
#
#                                 Shooting Draft - September 9, 2005
#                                Blue Revisions - September 15, 2005
#                                Pink Revisions - September 20, 2005
#                                  Green Revisions - October 9, 2005
#                                Yellow Revisions - November 9, 2005
#                            Goldenrod Revisions - November 14, 2005
#                                Salmon Revisions - December 9, 2005
#                                               2nd Blue In Progress
#
#  Hi. I have an appointment with... 0.59
# 3        MUSIC UP
#  Hi. I have an appointment with... 0.534
# 4
#  Hi. I have an appointment with... 0.275
# 5        FADE IN
# ...

# %%
from fuzzywuzzy import fuzz
fuzz.ratio('Deluxe Room, 1 King Bed', 'Deluxe King Room')
# Out:
# C:\Users\tirun\anaconda3\lib\site-packages\fuzzywuzzy\fuzz.py:11: UserWarning: Using slow pure-python SequenceMatcher. Install python-Levenshtein to remove this warning
#   warnings.warn('Using slow pure-python SequenceMatcher. Install python-Levenshtein to remove this warning')
# 62

# %%
pip install fuzzywuzzy
# Out:
# ...
#
# [notice] A new release of pip available: 22.1.2 -> 22.3
# [notice] To update, run: python.exe -m pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
from fuzzywuzzy import fuzz
def compare3(str1,str2):
    return(fuzz.ratio(str1, str2))
# Out:
# C:\Users\tirun\anaconda3\lib\site-packages\fuzzywuzzy\fuzz.py:11: UserWarning: Using slow pure-python SequenceMatcher. Install python-Levenshtein to remove this warning
#   warnings.warn('Using slow pure-python SequenceMatcher. Install python-Levenshtein to remove this warning')

# %%
count=1
a,b = sub_text[5]
while count<500:
    if(len(a)==0 or len(new_list[count])==0):
        print("EMPTY")
        continue
    print(count,new_list[count],a,compare3(a,new_list[count]))
    count+=1
# Out:
# 1                         THE DEVIL WEARS PRADA
#  Okay. So I was Miranda's
# second assistant... 9
# 2
#
#
#                              Written by
#
#                         Aline Brosh McKenna
#
#
#
#              Based on the novel by Lauren Weisberger
#
#
#
#
#                                 Shooting Draft - September 9, 2005
#                                Blue Revisions - September 15, 2005
#                                Pink Revisions - September 20, 2005
#                                  Green Revisions - October 9, 2005
#                                Yellow Revisions - November 9, 2005
#                            Goldenrod Revisions - November 14, 2005
#                                Salmon Revisions - December 9, 2005
#                                               2nd Blue In Progress
#
#  Okay. So I was Miranda's
# second assistant... 1
# 3        MUSIC UP
#  Okay. So I was Miranda's
# second assistant... 20
# 4
#  Okay. So I was Miranda's
# ...

# %%
import re
max_thres = 0
count=1
a,b = sub_text[3]
a = re.sub(r"[\n\t\s]+", " ", a)
#print("A: ",a)
while count<len(new_list):
    scr = re.sub(r"[\n\t\s]+", " ", new_list[count])
    #print("SCR:  ",scr)
    
    
    thres = compare4(a,scr)
    if(thres > max_thres):
        max_thres = thres
        script_max = new_list[count]
        #script_max = scr
    count+=1
    
print(script_max,a,max_thres,count,sep="\n")
# Out:
# 1      ...wiped off by ANDY SACHS, 20's, pretty but not glamorous,            1
#        smart but green, hair up in a towel, brushing her teeth. We
#        intercut ANDY getting ready and...
#
#        ... we see three or four other GIRLS getting ready too.
#
# 1A     A drawer filled with about forty lipsticks slides into                1A
#        frame... One of the GIRLS carefully applies shiny lip gloss
#        with a brush... ANDY puts on cherry Chapstick...
#
# 1B&C   A lacy thong floats through the air... one of the GIRLS pulls        1B&C
#        it up her glossy legs... A comfy cotton pair of Jockey
#        bikinis is tugged out of a pile... ANDY pulls them on...
#
# 1D     A gorgeous pair of slingback heels. One of the GIRLS pulls            1D
#        the shoes on while her model handsome boyfriend reclines on
#        crisp white sheets, watching her.
#
# 1E     A pair of comfortable wedges... ANDY dresses while NATE,              1E
# ...

# %%
s = '                Honey, you want West 57th.\r\n\r\n'
s1= '     '
match = re.compile( '(\s{16})((\w+\W? )+).' )
expr = match.findall(s) 
print(expr)
print(bool(expr))
# Out:
# [('                ', 'Honey, you want West ', 'West ')]
# True

# %%
import re
def isDialogue(string):
    match = re.compile( '(\s{16})((\w+\W? )+).' )
    expr = match.findall(string) 
    print("Dialogue:  ",expr)
    return bool(expr)

# %%
import re

def isSceneStart(string):
    flag=0
    for letter in string:
        if string[0].isdigit():
            if(letter.isdigit()):
                flag=1
                continue
            elif(letter == " "):
                break
            else:
                break
        elif string[0]==" ":
            if(checkSpaces(string)>=3 and checkSpaces(string)<7):
                flag = 1
                break
        else:
            return False
        
    
    match = re.compile('[^\<b>[0-9]+\s|\s\s|\s\s\s|\s\s\s\s[A-Z]+.')
    expr = match.findall(string)
    print("Scene:  ",expr)
    return bool(match)

# %%
s = '                Honey, you want West 57th.\r\n\r\n'
s1= '                             ANDY\r\n'
match = re.compile( '\s{24}[A-Z]+.' )
expr = match.findall(s1) 
print(expr)
print(bool(expr))
# Out:
# ['                        ANDY\r']
# True

# %%
def isCharacter(string):
    match = re.compile( '\s{24}[A-Z]+.' )
    expr = match.findall(string)
    print("Char:  ",expr)
    return bool(match)

# %%
"""dialogue_list = []
scene = 1


for line in new_list:
    if(isSceneStart(line)):
        scene+=1
    elif(isCharacter(line)):
        continue
    elif(isDialogue(line)):
        print("dialogue found!!")
        dialogue_list.append(scene,line)
    print("scene no ",scene)
    #print(dialogue_list)
    """
# Out:
# 'dialogue_list = []\nscene = 1\n\n\nfor line in new_list:\n    if(isSceneStart(line)):\n        scene+=1\n    elif(isCharacter(line)):\n        continue\n    elif(isDialogue(line)):\n        print("dialogue found!!")\n        dialogue_list.append(scene,line)\n    print("scene no ",scene)\n    #print(dialogue_list)\n    '

# %%
def compare4(str1,str2):  
    
    if(str2==" " or str1==" "):
        return 0
    
    elif(len(str2)<len(str1)):
        count=0
        l1=str1.split(" ")
        l2=str2.split(" ")
        t_len=len(l2)
        for word in l2:
            word = re.sub(r"[^\w\s]", '', word)
            for word2 in l1:
                word2 = re.sub(r"[^\w\s]", '', word2)
                if(word.lower()==word2.lower()):
                    
                    count+=1
                    break
        return(count/t_len)
    else:
        count=0
        l1=str1.split(" ")
        l2=str2.split(" ")
        t_len=len(l1)
        for word in l1:
            word = re.sub(r"[^\w\s]", '', word)
            for word2 in l2:
                word2 = re.sub(r"[^\w\s]", '', word2)
                if(word.lower()==word2.lower()):
                    count+=1
                    break
        return(count/t_len)

# %%
def isSceneStart(s):
    match = re.compile(r"([0-9]+(\s{3}|\s{4}|\s{5}|\s{6})([A-Z]+\s?\W*\s?)+[A-Z]+\s+[0-9]+)")
    expr = match.findall(s) 
    if(len(expr)==0):
        return False
    return(expr[0][0]==s)

# %%
#def update_scene(scene_num, timestamp,movie_list):

# %%
scene_start = False
sub=1
scene = 0
movie_list = []

for line in new_list:
    diag,ts = sub_text[sub]
    
    diag = re.sub(r"[\n\t\s]+", " ", diag)
    line = re.sub(r"[\n\t\s]+", " ", line)
    print("Diag: ",diag)
    print("Line:  ",line)
    
    if(isSceneStart(line)):
        scene_start = True
        scene+=1
        print("*********Scene Found************")
        continue
    if(scene_start==True):  
        if(compare4(diag,line)>0.7):
            scene_start = False
            #update_scene(scene,ts)
            movie_list.append(scene,ts)
            #print(movie_list)
            sub+=1
            nxt_diag,nxt_ts = sub_text[sub+1]
            nxt_diag = re.sub(r"[\n\t\s]+", " ", nxt_diag)
            if(compare4(nxt_diag,line)>0.7):
                sub+=1
# Out:
# Diag:  Hi. I have an appointment with...
# Line:
# Diag:  Hi. I have an appointment with...
# Line:    THE DEVIL WEARS PRADA
# Diag:  Hi. I have an appointment with...
# Line:    Written by Aline Brosh McKenna Based on the novel by Lauren Weisberger Shooting Draft - September 9, 2005 Blue Revisions - September 15, 2005 Pink Revisions - September 20, 2005 Green Revisions - October 9, 2005 Yellow Revisions - November 9, 2005 Goldenrod Revisions - November 14, 2005 Salmon Revisions - December 9, 2005 2nd Blue In Progress
# Diag:  Hi. I have an appointment with...
# Line:    MUSIC UP
# Diag:  Hi. I have an appointment with...
# Line:
# Diag:  Hi. I have an appointment with...
# Line:    FADE IN
# Diag:  Hi. I have an appointment with...
# Line:
# Diag:  Hi. I have an appointment with...
# Line:    STEAM ON A MIRROR
# Diag:  Hi. I have an appointment with...
# ...

# %%
print(movie_list)
# Out:
# []

# %%
import re
#s ='29    EXT. STARBUCKS -- DAY                                                    29'
#match = re.compile('[^\<b>[0-9]+\s|\s\s|\s\s\s|\s\s\s\s[A-Z]+[0-9]+ ')
#match = re.compile(r'[0-9]+\s{3-6}([A-Z]+\s?\W*\s?)+[A-Z]+\s+[0-9]+')
#s = "The GIRLS, looking flawless, fold their legs into taxis and town cars as ANDY trots down the street and into the subway. "
s = "32   CONTINUED: (2)                                                         32"
match = re.compile(r"([0-9]+\s+(CONTINUED:)(\s+\([0-9]\))?\s+[0-9]+.)")
expr = match.findall(s) 
if(len(expr)==0): 
    print(False) 
    
else:
    print(expr[0][0])
    print(expr[0][0]==s)
# Out:
# 32   CONTINUED: (2)                                                         32
# True

# %%
import re
isSceneStart('The GIRLS, looking flawless, fold their legs into taxis and town cars as ANDY trots down the street and into the subway. ')
# Out:
# False
